# %% [markdown]
# # 抓取HTML

# %%
import urllib2
response=urllib2.urlopen("https://zhuanlan.zhihu.com/p/21479334")

# %% [markdown]
# 首先简单的反问一个知乎页面

# %%
print response.read()
# Out:
# <!doctype html>
# <html lang="zh-CN" class="">
#   <head>
#     <meta charset="utf-8">
#     <meta http-equiv="X-UA-Compatible" content="IE=edge">
#     <title>如何学习Python爬虫[入门篇]？ - 知乎专栏</title>
#     <meta name="viewport" content="width=device-width, initial-scale=1.0, maximum-scale=1.0, user-scalable=0">
#     <link rel="shortcut icon" href="https://static.zhihu.com/static/favicon.ico" type="image/x-icon">
#     <link rel="stylesheet" href="//static.zhihu.com/hemingway/app.74a20de34be20ddefbaa528da12d79f0.css" />
#     <style></style>
#     <script>document.documentElement.className += ('ontouchstart' in window) ? ' touch' : ' no-touch'</script>
#   </head>
#   <body>
#
#     <div id="react-root"></div>
# ...

# %% [markdown]
# 可以读取HTML信息

# %% [markdown]
# 有些时候还要加header 和 cookies
# 还可以进行post操作

# %% [raw]
# import urllib2
#
# data={
#     "username":"xxx"
#     "password":"xxx"
# }
# request=urllib2.Request("http://xxx.com",data)
# response=urllib2.urlopen(request)

# %% [raw]
# import urllib2
#
# path="xxx.png"
# url="http://zhaduixueshe.com/static/pic/discovery.png"
#
# urllib.urlretrieve(url,path)

# %% [markdown]
# 还可以爬取图片

# %% [markdown]
# # requests

# %% [markdown]
# 更强大的库

# %%
import requests
import re
#coding=utf8

request_headers={'Accept':'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8',
'Cookie':'q_c1=f1226ea197fa4e4b94d5a92704874c45|1495899998000|1495899998000; r_cap_id="N2RmNjNiZTJmYjY0NGM2MGIyZjEyNzA4NzkzMzczMDQ=|1495899998|6e906dc38aebd939f8ba730c7c1aa7ef29b5ef6d"; cap_id="ZGEyZDJiMmRmZGY4NDgwYWJhZTBhNTZhZWE3MTZhMDg=|1495899998|4a96fd66c1e6afd077c5fdfd36fb4165e5163e33"; _zap=3e505dd0-7259-4174-b0da-30c38c76572e; d_c0="ADBCXk-50guPTpeTFGS2GAroTFZD9fWLSqM=|1495900000"; _xsrf=9f5824b2f764a2bd0b563330f0afec6b; s-t=autocomplete; s-q=python%20%E7%88%AC%E8%99%AB; s-i=5; sid=648nkoig; __utma=51854390.1923978876.1495899998.1496936152.1496944634.20; __utmc=51854390; __utmz=51854390.1496931582.18.3.utmcsr=zhihu.com|utmccn=(referral)|utmcmd=referral|utmcct=/; __utmv=51854390.100-1|2=registration_date=20141207=1^3=entry_date=20141207=1; z_c0=Mi4wQUFBQVRrNURBQUFBTUVKZVQ3blNDeGNBQUFCaEFsVk5jaXhSV1FETzFKRC1kQW5XaHBHUmxtTmNST1p0b1c0ZmlR|1496944964|5b549cd979a4898a77a1d9afc4e8e5c45a62ccee',
'Host':'www.zhihu.com',
'Referer':'https://zhuanlan.zhihu.com/p/25198314',
'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.36'}

url="https://www.zhihu.com/people/excited-vczh/activities"

z=requests.get(url,headers=request_headers)
print z.content
# Out:
# <!doctype html>
# <html lang="zh" data-reactroot="" data-reactid="1" data-react-checksum="1957730512"><head data-reactid="2"><meta charset="utf-8" data-reactid="3"/><title data-react-helmet="true" data-reactid="4">vczh - 知乎</title><meta name="viewport" content="width=device-width,initial-scale=1,maximum-scale=1" data-reactid="5"/><meta name="renderer" content="webkit" data-reactid="6"/><meta name="force-rendering" content="webkit" data-reactid="7"/><meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1" data-reactid="8"/><meta name="google-site-verification" content="FTeR0c8arOPKh8c5DYh_9uu98_zJbaWw53J-Sch9MTg" data-reactid="9"/><meta data-react-helmet="true" name="apple-itunes-app" content="app-id=432274380,
# ...

# %% [markdown]
# http://www.python-requests.org/en/master/user/quickstart/ 官方文档
